# %% [markdown]
# #
# - a. A descriptive analysis of the additives (columns named as “a” to “i”), which must include summaries of findings (parametric/non-parametric).
# - b. Correlation and ANOVA, if applicable, is a must.
# - c. A graphical analysis of the additives, including a distribution study.
# - d. A clustering test of your choice (unsupervised learning), to determine the distinctive number of formulations present in the dataset.

# %%
import numpy as np
import pandas as pd

# %%
ingredients = pd.read_csv('ingredient.csv')

# %%
ingredients.head(5)
# Out:
#          a      b     c     d      e     f      g     h     i
# 0  1.51735  13.02  3.54  1.69  72.73  0.54   8.44  0.00  0.07
# 1  1.53125  10.73  0.00  2.10  69.81  0.58  13.30  3.15  0.28
# 2  1.52300  13.31  3.58  0.82  71.99  0.12  10.17  0.00  0.03
# 3  1.51768  12.56  3.52  1.43  73.15  0.57   8.54  0.00  0.00
# 4  1.51813  13.43  3.98  1.18  72.49  0.58   8.15  0.00  0.00

# %%
ingredients.info()
#ingredients.shape
#ingredients.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       214 non-null    float64
#  1   b       214 non-null    float64
#  2   c       214 non-null    float64
#  3   d       214 non-null    float64
#  4   e       214 non-null    float64
#  5   f       214 non-null    float64
#  6   g       214 non-null    float64
#  7   h       214 non-null    float64
#  8   i       214 non-null    float64
# dtypes: float64(9)
# memory usage: 15.1 KB

# %% [markdown]
# #
# ** Observations:
# - columns: 9
# - rows: 214
# - all columns type - float
# - No missing values

# %%
#descriptive statistics
#print('Column:', ingredients.columns[0])
#print('Mean:',round(ingredients[ingredients.columns[0]].mean(),2))
#print('Median:',round(ingredients[ingredients.columns[0]].median(),2))
ingredients.describe()
# Out:
#                 a           b           c           d           e           f  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516523   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                 g           h           i
# count  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009
# std      1.423153    0.497219    0.097439
# min      5.430000    0.000000    0.000000
# 25%      8.240000    0.000000    0.000000
# ...

# %% [markdown]
# ### Summary - Column level Observatoins:
#
# #### Column 'a' :
#             - Nulls: 0
#             - No outliers
#             - Meand and Median(50%) are close
#             - No variance
# #### Column 'b' :
#             - Nulls: 0
#             - No outliers
#             - Meand and Median(50%) are close
#             - No variance
# #### Column 'c' :
#             - Nulls: 0
#             - No outliers
#             - Meand and Median(50%) are close
#             - Variance Presence
# #### Column 'd' :
#             - Nulls: 0
#             - No outliers
#             - Meand and Median(50%) are close
#             - No variance
# #### Column 'e' :
#             - Nulls: 0
#             - No outliers
#             - Meand and Median(50%) are close
#             - No variance
# #### Column 'f' :
#             - Nulls: 0
#             - outliers (top side)
#             - Meand and Median(50%) are close
#             - No variance
# #### Column 'g' :
#             - Nulls: 0
#             - outliers (top side)
#             - Meand and Median(50%) are close
#             - Variance Presence
# #### Column 'h' :
#             - Nulls: 0
#             - outliers (top side)
#             - Meand and Median(50%) are close
#             - No variance
# #### Column 'i' :
#             - Nulls: 0
#             - No outliers
#             - Meand and Median(50%) are close
#             - No variance

# %% [markdown]
# ### Correlation

# %%
round(ingredients.corr(),2)
# Out:
#       a     b     c     d     e     f     g     h     i
# a  1.00 -0.19 -0.12 -0.41 -0.54 -0.29  0.81 -0.00  0.14
# b -0.19  1.00 -0.27  0.16 -0.07 -0.27 -0.28  0.33 -0.24
# c -0.12 -0.27  1.00 -0.48 -0.17  0.01 -0.44 -0.49  0.08
# d -0.41  0.16 -0.48  1.00 -0.01  0.33 -0.26  0.48 -0.07
# e -0.54 -0.07 -0.17 -0.01  1.00 -0.19 -0.21 -0.10 -0.09
# f -0.29 -0.27  0.01  0.33 -0.19  1.00 -0.32 -0.04 -0.01
# g  0.81 -0.28 -0.44 -0.26 -0.21 -0.32  1.00 -0.11  0.12
# h -0.00  0.33 -0.49  0.48 -0.10 -0.04 -0.11  1.00 -0.06
# i  0.14 -0.24  0.08 -0.07 -0.09 -0.01  0.12 -0.06  1.00

# %% [markdown]
# ### Correlation Analysis
#     - a and g are having strong positive correlation (0.81)
#     - No strong negative correlation - but a and e are having moderate negative correlation (-0.54)

# %% [markdown]
# #### Variable level Analysis - Graphical and Distribution Study

# %% [markdown]
# ##### Corretion

# %%
import seaborn as sns

# %%
#plotting the heatmap for correlation
sns.heatmap(round(ingredients.corr(),2), annot=True,cmap='RdYlGn')

# %% [markdown]
# ##### Box plot & Historim for distribution Analysis

# %%
bp1 = ingredients.boxplot()
hist1= ingredients.hist()

# %% [markdown]
# ##### Observations:
# - Boxplot is clusttered due to scale difference across variables
# - From the Histogram - f,h,i are having skewed distribution
#
# *** Performing variable level analysis

# %%
import matplotlib.pyplot as plt

# %%
def box_plot(df, col):
    df = df.copy()
    plt.boxplot(df[col])
    plt.title(col)
    plt.show()
    
for col in ingredients.columns:
    box_plot(ingredients, col)

# %%
def hist_plot(df, col):
    df = df.copy()
    df[col].hist(bins=20)
    plt.ylabel('cnt')
    plt.xlabel(col)
    plt.title(col)
    plt.show()
    
for col in ingredients.columns:
    hist_plot(ingredients, col)

# %% [markdown]
# ### Summary of observations:
# - From the Histogram - f,h,i are having skewed distribution.
# - Positively corelated: a & g
# - Negatively corelated: e & a

# %% [markdown]
# #### Kmeans and hierarchical clustering

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

# %%
X = ingredients.copy()

# %%
SS = []
for cluster in range(1, 11):
    kmeans = KMeans(n_clusters=cluster, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    SS.append(kmeans.inertia_)
plt.plot(range(1, 11), SS)
plt.title('Elbow Plot')
plt.xlabel('Number of clusters')
plt.ylabel('SS')
plt.show()

# %%
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(X, method = 'ward'))
plt.title('Dendograms')
plt.xlabel('Ingredients')
plt.ylabel('Euclidean distances')
plt.show()

# %% [markdown]
# Observations:
# - As per both Elbow and hierarchical analysis (high level), there are 3 clusters
